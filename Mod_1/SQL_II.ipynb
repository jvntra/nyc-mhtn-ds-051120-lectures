# %% [markdown]
# # SQL II: Grouping and Joining
#
# _May 18, 2020_
#
# Agenda:
# - Practice with Grouping in SQLite
# - Practice with different types of Joins in SQLite

# %% [markdown]
# <img src = "https://media.giphy.com/media/3oKIPnAiaMCws8nOsE/giphy.gif">

# %%
import sqlite3
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Part I. Grouping
# Just like pandas, Sql support different types of grouping statements for performing aggregate functions and allow us to calculate various statistics for data.
#
# Syntax:
# `SELECT * FROM tables GROUP BY column`

# %%
# instantiate some data
auto = pd.read_csv('auto-mpg.csv')
tips = sns.load_dataset('tips')
small_quiz = pd.DataFrame({"students":["Muriel","JP","Danny"],
                          "projects":[1,2,1],
                          "grades":np.random.randint(80,100,3)})
small_grades = pd.DataFrame({"students":["Kevin","JP","Dipta"],
                            "quiz_score":np.random.randint(0,10,3)})

# %%
conn = sqlite3.connect('aggregate.db')
c = conn.cursor()

# %%
# insert these datasets into our db
auto.to_sql('auto', con=conn)
tips.to_sql('tips', con=conn)
small_grades.to_sql('small_grade', con=conn)
small_quiz.to_sql('small_quiz',con=conn)
# Out:
# /Users/flee/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2531: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype, method=method)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-592e089fd125> in <module>
#       1 # insert these datasets into our db
# ----> 2 auto.to_sql('auto', con=conn)
#       3 tips.to_sql('tips', con=conn)
#       4 small_grades.to_sql('small_grade', con=conn)
#       5 small_quiz.to_sql('small_quiz',con=conn)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1544                             if_exists=if_exists, index_label=index_label,
#    1545                             dtype=dtype)
# -> 1546         table.create()
#    1547         table.insert(chunksize, method)
#    1548
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     573             if self.if_exists == 'fail':
#     574                 raise ValueError(
# --> 575                     "Table '{name}' already exists.".format(name=self.name))
#     576             elif self.if_exists == 'replace':
#     577                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'auto' already exists.

# %%
# for the tips df/table, get the total number of man and woman who tips
tips.groupby('sex').sex.value_counts()
# Out:
# sex     sex
# Male    Male      157
# Female  Female     87
# Name: sex, dtype: int64

# %%
# in sql 
query = None
c.execute(query).fetchall()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-1a1d3f779b9f> in <module>
#       1 # in sql
#       2 query = None
# ----> 3 c.execute(query).fetchall()
#
# ValueError: operation parameter must be str

# %%
# using pandas, select the average amount tipped for time
tips.groupby('time').tip.mean()
# Out:
# time
# Lunch     2.728088
# Dinner    3.102670
# Name: tip, dtype: float64

# %%
# use sql to recreate this query
query = None
c.execute(query).fetchall()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d6fe9ce59cb8> in <module>
#       1 # use sql to recreate this query
#       2 query = None
# ----> 3 c.execute(query).fetchall()
#
# ValueError: operation parameter must be str

# %% [markdown]
# We can also use `GROUP BY` with certain conditions, in conjunction with filtering and ordering.

# %%
# use pandas, get the average total bills for a party larger than 2 for every size of party
tips.groupby(['size']).total_bill.mean()[2:]
# Out:
# size
# 3    23.277632
# 4    28.613514
# 5    30.068000
# 6    34.830000
# Name: total_bill, dtype: float64

# %%
# use sql to recreate this query
query = None
c.execute(query).fetchall()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d6fe9ce59cb8> in <module>
#       1 # use sql to recreate this query
#       2 query = None
# ----> 3 c.execute(query).fetchall()
#
# ValueError: operation parameter must be str

# %%
# your turn - use pandas, get the maximum value of total bill for female non smoker
tips[(tips.sex == 'Female') & (tips.smoker == 'No')].total_bill.max()
# Out:
# 35.83

# %%
# use sql to recreate this query
query = """SELECT MAX(total_bill) FROM TIPS GROUP BY sex smoker WHERE sex = 'Female' and smoker = 'No'"""
c.execute(query).fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-16-0eff76052080> in <module>
#       1 # use sql to recreate this query
#       2 query = """SELECT MAX(total_bill) FROM TIPS GROUP BY sex smoker WHERE sex = 'Female' and smoker = 'No'"""
# ----> 3 c.execute(query).fetchall()
#
# OperationalError: near "smoker": syntax error

# %%
# your turn - use pandas, get the average tip values for different size groups, and show top 2
# most amount of average tips

# %%
# use sql 
query = None 
c.execute(query).fetchall()

# %% [markdown]
# ## Part II. Join
#
# Based on this diagram, how would you explain the different types of joins?
#
# <img src = 'sql-joins.png' width = 400>

# %%
print(small_grades)
print(small_quiz)

# %%
# left join - join small quiz with small grades, on student name
small_grades.merge(small_quiz, on = 'students', how = "left")

# if i run this command, what would happen? how many observations/record?

# %%
# sql 
query = """SELECT * FROM small_grade LEFT JOIN small_quiz ON small_grade.students = small_quiz.students"""
c.execute(query).fetchall()

# %%
# inner join and get the student's grades
small_grades.merge(small_quiz, on = 'students', how = 'inner')

# %%
query = """SELECT grades FROM small_grade INNER JOIN small_quiz ON small_grade.students = small_quiz.students"""
c.execute(query).fetchall()

# %%
# your turn - use right join and get all entries

# pandas

# %%
# sql
